# %% [markdown]
# # Installing TensorFlow in Jupyter Notebook
#
# **Name:** Ayush
# **Course / Lab:** Deep Learning Lab
# **Experiment No:** 1
# **Date:** 29 Jan 2026
#
# ---

# %% [markdown]
# ## Aim
#
# To install TensorFlow and verify its successful execution inside a Jupyter Notebook environment.

# %% [markdown]
# ## Software & Tools Required
#
# - Python 3.9 or above
# - pip (Python package manager)
# - TensorFlow
# - Jupyter Notebook / Jupyter Lab
# - Operating System: Windows

# %% [markdown]
# ## Procedure
#
# 1. Open Terminal
# 2. Install TensorFlow using pip.
# 3. Install Jupyter Notebook and required kernel.
# 4. Launch Jupyter Notebook.
# 5. Create a new Python notebook.
# 6. Run verification code to confirm TensorFlow installation.

# %%
# %pip install tensorflow

# %% [markdown]
# ## Verification of TensorFlow Installation
#
# The following code imports TensorFlow and checks:
# - Installed TensorFlow version
# - Keras version
# - GPU availability
# - Tensor computation functionality

# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

# Simple tensor computation test
tensor_test = tf.reduce_sum(tf.random.normal([500, 500]))
print("Simple tensor test:", tensor_test)

# %% [markdown]
# ## Result
#
# -  TensorFlow was successfully installed and verified inside the Jupyter Notebook environment.
# -  The system is now ready for neural network and deep learning experiments.

# %% [markdown]
# ## Conclusion
#
# The successful execution of TensorFlow operations confirms that the software environment
# is correctly configured. This setup can be used for implementing and training neural
# network models in future laboratory experiments.

# %% [markdown]
# ## Version Control (Git)
#
# This notebook is maintained under Git version control to ensure reproducibility,
# collaboration, and proper experiment tracking.
#
# Repository includes:
# - Jupyter Notebook
# - requirements.txt
# - README.md
# - .gitignore
